# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Visualization of Entity Distribution (From EntityDistribution_testsets.ipynb)
def plot_entity_distribution(counts_dict):
    plt.figure(figsize=(12, 6))
    # ... [Logic to create grouped bar chart from your original code] ...
    plt.title("Entity Distribution Across Datasets")
    plt.savefig("notebooks/plots/entity_distribution.png")
    plt.show()

# 2. F1 Comparison Heatmaps (From Figure.ipynb & F1comparison.ipynb)
def plot_f1_heatmap(data_matrix):
    plt.figure(figsize=(10, 8))
    sns.heatmap(data_matrix, annot=True, cmap="YlGnBu", fmt=".2f")
    plt.title("F1-Score Comparison: WG-BERT vs RoBERTa vs GLiNER")
    plt.savefig("notebooks/plots/f1_heatmap.png")
    plt.show()

# 3. GLiNER Zero-Shot Evaluation (From GLiner.ipynb)
from gliner import GLiNER
model_gliner = GLiNER.from_pretrained("numind/NuNER-Zero")

def evaluate_gliner(test_texts, labels):
    # Logic to predict and compare with Gold/Adversarial labels
    pass

# Run all figures used in the paper
# plot_entity_distribution(counts)
# plot_f1_heatmap(results_df)
